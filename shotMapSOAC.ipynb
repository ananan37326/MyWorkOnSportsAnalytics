# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patheffects as path_effects

from mplsoccer import VerticalPitch

# %%
df = pd.read_csv('efl_championship_shots_07022022-2.csv',index_col=0)

# %%
df
# Out:
#        matchId        playerName  playerId  min           x          y  \
# 0      3414545      Daryl Horgan    253356    2  101.681034  37.431250
# 1      3414545      Joe Jacobson     28892   10   58.193332  48.554906
# 2      3414545    Kieran Sadlier    614458   12   73.024756  29.967858
# 3      3414545   Michael Ihiekwe    280865   12   94.385966  29.715713
# 4      3414545  Chiedozie Ogbene    674009   28   91.900002  23.929172
# ...        ...               ...       ...  ...         ...        ...
# 25207  3620506   Darnell Furlong    609733   69  101.301723  26.574375
# 25208  3620506    Grady Diangana    654091   74   97.473683  45.612227
# 25209  3620506  Victor Adeboyejo    592210   85   94.578946  30.328000
# 25210  3620506      Caleb Taylor   1194286   87   98.535085  36.134999
# 25211  3620506      Caleb Taylor   1194286   87   99.210528  32.856250
#
#         shotType  blocked  onTarget  ownGoal        xG    xGOT     eventType  \
# 0       LeftFoot    False     False    False  0.799400     NaN          Miss
# 1       LeftFoot    False     False    False  0.029000     NaN          Miss
# 2      RightFoot    False      True    False  0.048400  0.3966  AttemptSaved
# 3         Header    False     False    False  0.041400     NaN          Miss
# 4       LeftFoot     True      True    False  0.049900     NaN  AttemptSaved
# ...          ...      ...       ...      ...       ...     ...           ...
# 25207  RightFoot     True      True    False  0.075121     NaN  AttemptSaved
# 25208   LeftFoot    False     False    False  0.058626     NaN          Miss
# 25209  RightFoot    False     False    False  0.193279     NaN          Miss
# 25210     Header     True      True    False  0.143543     NaN  AttemptSaved
# 25211     Header    False     False    False  0.248859     NaN          Miss
#
#        teamId teamColor                 date              teamName
# 0        8676   #083868  2020-09-12 13:30:00     Wycombe Wanderers
# 1        8676   #083868  2020-09-12 13:30:00     Wycombe Wanderers
# 2        8119   #DA291C  2020-09-12 13:30:00      Rotherham United
# 3        8119   #DA291C  2020-09-12 13:30:00      Rotherham United
# 4        8119   #DA291C  2020-09-12 13:30:00      Rotherham United
# ...       ...       ...                  ...                   ...
# 25207    8659   #1a237e  2022-05-07 13:30:00  West Bromwich Albion
# 25208    8659   #1a237e  2022-05-07 13:30:00  West Bromwich Albion
# 25209    8283   #881018  2022-05-07 13:30:00              Barnsley
# 25210    8659   #1a237e  2022-05-07 13:30:00  West Bromwich Albion
# 25211    8659   #1a237e  2022-05-07 13:30:00  West Bromwich Albion
#
# [25212 rows x 17 columns]

# %%
fig = plt.figure(figsize=(4,4),dpi=100)
ax = plt.subplot(111,aspect)

pitch = VerticalPitch()
pitch.draw(ax)
